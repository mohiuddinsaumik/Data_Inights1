# %% [markdown]
# <a href="https://colab.research.google.com/github/mohiuddinsaumik/Data_Inights1/blob/main/Innovation_Skills_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot_2.png](data:image/png;base64,...)

# %% [markdown]
# # T A S K - 0 1

# %%
length = int(input("Enter Length : "))
width = int(input("Enter Width : "))
area = (length * width)

print ('You have to paint {} meters area.'.format(area))
# Out:
# Enter Length : 33
# Enter Width : 2
# You have to paint 66 meters area.

# %% [markdown]
# # T A S K - 0 2

# %%
pi = 3.1416
r = float(input("Enter Redius : "))

area = pi* (r**2)

print('Tiles need {} Meters'.format(area))
# Out:
# Enter Redius : 4
# Tiles need 50.2656 Meters

# %% [markdown]
# # T A S K - 0 3

# %% [markdown]
# # T E S K - 0 5![Screenshot (336).png](data:image/png;base64,...)

# %%
initial_investment = 5000
interest = int(input("Enter Value : "))

return_value = (interest-initial_investment)/initial_investment

print(return_value)
# Out:
# Enter Value : 50
# -0.99
